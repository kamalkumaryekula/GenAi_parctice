# %% [markdown]
# pipelines

# %%
'''A pipeline is simply a sequence of steps arranged in order,
where the output of one step becomes the input of the next.
Purpose: Automate code integration and deployment.
Steps:
    Code commit → Build → Test → Deploy
    
Raw Data --> Cleaning --> Feature Engineering --> Model Training --> Evaluation --> Deployment
'''
# Out:
# 'A pipeline is simply a sequence of steps arranged in order,\nwhere the output of one step becomes the input of the next.\nPurpose: Automate code integration and deployment.\nSteps:\n    Code commit → Build → Test → Deploy\n\nRaw Data --> Cleaning --> Feature Engineering --> Model Training --> Evaluation --> Deployment\n'
