# %%
import csv
from pprint import pprint


with open("C:/Users/Admin/OneDrive/Documents/students_data.csv" , newline = "") as f:
    reader = csv.reader(f)
    data = list(reader)

pprint(data)

with open("C:/Users/Admin/OneDrive/Documents/faculties_data.csv", newline = "") as f_one:
    reader_one = csv.reader(f_one)
    data_one = list(reader_one)

#pprint(data_one)
# Out:
# [['student1', 'Mathematics', '88'],
#  ['student1', 'Telugu', '3'],
#  ['student1', 'English', '24'],
#  ['student1', 'Social', '59'],
#  ['student1', 'Physics', '18'],
#  ['student1', 'Chemistry', '80'],
#  ['student2', 'Mathematics', '74'],
#  ['student2', 'Telugu', '87'],
#  ['student2', 'English', '33'],
#  ['student2', 'Social', '72'],
#  ['student2', 'Physics', '56'],
#  ['student2', 'Chemistry', '81'],
#  ['student3', 'Mathematics', '35'],
#  ['student3', 'Telugu', '58'],
#  ['student3', 'English', '98'],
#  ['student3', 'Social', '82'],
#  ['student3', 'Physics', '10'],
#  ['student3', 'Chemistry', '47'],
#  ['student4', 'Mathematics', '9'],
#  ['student4', 'Telugu', '92'],
#  ['student4', 'English', '89'],
#  ['student4', 'Social', '56'],
#  ['student4', 'Physics', '50'],
#  ['student4', 'Chemistry', '27'],
#  ['student5', 'Mathematics', '99'],
#  ['student5', 'Telugu', '8'],
#  ['student5', 'English', '54'],
#  ['student5', 'Social', '41'],
# ...

# %%
#1. Find the faculty with highest student count who got more than 90%.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #1. Find the faculty with highest student count who got more than 90%.
# ----> 2 m = max[data,key:lambda x:data[2]]
#       3 print(m)
#
# NameError: name 'data' is not defined
